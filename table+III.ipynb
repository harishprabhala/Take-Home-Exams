# %%
% matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv('/Users/harishprabhala/Downloads/TABLE_III._Deaths_in_122_U.S._cities.csv', encoding='mac_roman')

# %%
data1.head(11)
# Out:
#         Reporting Area  MMWR YEAR  MMWR WEEK  \
# 0          New England       2016          1
# 1        Mid. Atlantic       2016          1
# 2         E.N. Central       2016          1
# 3         W.N. Central       2016          1
# 4          S. Atlantic       2016          1
# 5         E.S. Central       2016          1
# 6         W.S. Central       2016          1
# 7             Mountain       2016          1
# 8              Pacific       2016          1
# 9                Total       2016          1
# 10  St. Petersburg, FL       2016          1
#
#     All causes, by age (years), All Ages**  \
# 0                                    600.0
# 1                                    807.0
# 2                                   2468.0
# 3                                    634.0
# 4                                   1402.0
# 5                                   1230.0
# 6                                   2167.0
# 7                                   1460.0
# ...

# %%
summary = data1.head(9)

# %%
summary
# Out:
#   Reporting Area  MMWR YEAR  MMWR WEEK  \
# 0    New England       2016          1
# 1  Mid. Atlantic       2016          1
# 2   E.N. Central       2016          1
# 3   W.N. Central       2016          1
# 4    S. Atlantic       2016          1
# 5   E.S. Central       2016          1
# 6   W.S. Central       2016          1
# 7       Mountain       2016          1
# 8        Pacific       2016          1
#
#    All causes, by age (years), All Ages**  \
# 0                                   600.0
# 1                                   807.0
# 2                                  2468.0
# 3                                   634.0
# 4                                  1402.0
# 5                                  1230.0
# 6                                  2167.0
# 7                                  1460.0
# 8                                  2021.0
#
#   All causes, by age (years), All Ages**, flag  \
# 0                                          NaN
# ...

# %%
import seaborn as sns

# %%
sample = summary[['Reporting Area','All causes, by age (years), All Ages**']].set_index('Reporting Area')

# %%
sample.sort_values('All causes, by age (years), All Ages**', ascending=False).plot(kind='Bar')

# %%
## N.E.Central and S.W.Central had the highest deaths whereas New England and N.W.Central had the lowest.

# %%
sample1 = summary[['Reporting Area','All causes, by age (years), ≥65']].set_index('Reporting Area')

# %%
sample1.sort_values('All causes, by age (years), ≥65', ascending=False).plot(kind='Bar')

# %%
## Deaths in older population was seen mostly in E.N.Central and Pacific

# %%
sample2 = summary[['Reporting Area','All causes, by age (years), 1-24']].set_index('Reporting Area')

# %%
sample2.sort_values('All causes, by age (years), 1-24', ascending=False).plot(kind='Bar')

# %%
## Deaths in the younger population was seen mostly in E.N.Central and W.S.Central

# %%
data1.groupby('Reporting Area')['All causes, by age (years), All Ages**'].sum().sort_values(ascending=False)
# Out:
# Reporting Area
# TotalÂ¶              437754.0
# E.N. Central          82833.0
# Pacific               68290.0
# Mid. Atlantic         64866.0
# W.S. Central          61326.0
# S. Atlantic           45190.0
# Mountain              44707.0
# E.S. Central          38943.0
# New York City, NY     38522.0
# W.N. Central          23875.0
# New England           20513.0
# Houston, TX           14254.0
# Total                 12789.0
# Las Vegas, NV         12728.0
# Los Angeles, CA       11709.0
# Cleveland, OH         10930.0
# Chicago, IL           10521.0
# San Antonio, TX        9873.0
# Columbus, OH           9240.0
# Sacramento, CA         8870.0
# Dallas, TX             8728.0
# San Jose, CA           8210.0
# Indianapolis, IN       7833.0
# Phoenix, AZ            7744.0
# Birmingham, AL         7245.0
# Memphis, TN            6797.0
# Nashville, TN          6770.0
# San Diego, CA          6515.0
# Tucson, AZ             6429.0
# Jacksonville, FL       6388.0
# ...

# %%
## Looking at major cities, New York City, Houston, Las Vegas and Los Angeles had the highest deaths.
